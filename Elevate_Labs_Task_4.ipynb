# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav-62/Elevate_Labs_Task_4/blob/main/Elevate_Labs_Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load Data and Identify Features

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load the dataset
df = pd.read_csv('adult.csv')

# Identify categorical and numerical features
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

print(f"Numerical: {numerical_cols}")
print(f"Categorical: {categorical_cols}")
# Out:
# Numerical: ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']
# Categorical: ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country', 'income']

# %% [markdown]
# 2. Encoding (Label & One-Hot)

# %%
#  Label Encoding for target 'income'
le = LabelEncoder()
df['income'] = le.fit_transform(df['income'])

#  One-Hot Encoding for other categorical features
# We use drop_first=True to avoid the dummy variable trap
df = pd.get_dummies(df, columns=[col for col in categorical_cols if col != 'income'], drop_first=True)

# %% [markdown]
# 3. Standard Scaling

# %%
#  Scale numerical features
scaler = StandardScaler()

# Exclude the target 'income' from scaling
cols_to_scale = [col for col in numerical_cols if col != 'income']
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %% [markdown]
# 4. Save Deliverables

# %%
#  Save processed dataset
df.to_csv('Preprocessed_Adult_Income.csv', index=False)
print("Preprocessed file saved successfully!")
# Out:
# Preprocessed file saved successfully!
